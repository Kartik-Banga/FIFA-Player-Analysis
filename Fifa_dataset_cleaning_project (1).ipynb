# %%
import pandas as pd

# %%
dataset = pd.read_csv('fifa21 raw data v2.csv')
# Out:
# <ipython-input-172-a7ba67dffda3>:1: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv('fifa21 raw data v2.csv')

# %%
df = dataset.copy()

# %%
df.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# Proportion of Null values

# %%
print('Missing data proportion:')
print(df.isnull().mean())
print("")
# Out:
# Missing data proportion:
# ID           0.00000
# Name         0.00000
# LongName     0.00000
# photoUrl     0.00000
# playerUrl    0.00000
#               ...
# PAS          0.00000
# DRI          0.00000
# DEF          0.00000
# PHY          0.00000
# Hits         0.13673
# Length: 77, dtype: float64

# %% [markdown]
# Columns containing null values

# %%
list_null = []
for column in df.columns:
  if df[column].isnull().any():
    list_null.append(column)

# %%
print(list_null)
# Out:
# ['Loan Date End', 'Hits']

# %% [markdown]
# Data type of each column

# %%
print('Data type of each column:')
print(df.dtypes)
# Out:
# Data type of each column:
# ID            int64
# Name         object
# LongName     object
# photoUrl     object
# playerUrl    object
#               ...
# PAS           int64
# DRI           int64
# DEF           int64
# PHY           int64
# Hits         object
# Length: 77, dtype: object

# %%
object_dtype = []
for column in df.columns:
  if df[column].dtype == 'object':
    object_dtype.append(column)

# %%
print(object_dtype)
# Out:
# ['Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Club', 'Contract', 'Positions', 'Height', 'Weight', 'Preferred Foot', 'Best Position', 'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'Hits']

# %% [markdown]
# Checking duplicates in some columns

# %% [markdown]
# 1) Checking duplicates in 'ID' column

# %%
if len(df['ID'].unique()) == len(df['ID']):
    print("Column has unique values.")
else:
    print("Column does not have unique values.")
# Out:
# Column has unique values.

# %% [markdown]
# 2) Checking duplicates in 'Name' column

# %%
if len(df['Name'].unique()) == len(df['Name']):
    print("Column has unique values.")
else:
    print("Column does not have unique values.")
# Out:
# Column does not have unique values.

# %% [markdown]
# 3) Checking duplicates in 'LongName' column

# %%
if len(df['LongName'].unique()) == len(df['LongName']):
    print("Column has unique values.")
else:
    print("Column does not have unique values.")
# Out:
# Column does not have unique values.

# %% [markdown]
# Therefore, column 'ID' has unique values while column 'Name'
# and 'LongName' have duplicate values.
# So to avoid confusion
# in the analysis part, duplicate entries in both column 'Name'
# and 'LongName' are dropped.

# %%
df = df.drop_duplicates(subset='Name')

# %%
df = df.drop_duplicates(subset='LongName')

# %% [markdown]
# Size of original dataset

# %%
print(len(df))
# Out:
# 17919

# %% [markdown]
# Dividing 'Contract' column to 'Contract start year' and 'Contract end year'

# %%
df['Contract_start_year'] = 0
df['Contract_end_year']   = 0
for i in range(len(df)):
  if len(df['Contract'].iloc[i]) == 11:
    temp = (df['Contract'].iloc[i]).split('~')
    df['Contract_start_year'][i] = temp[0]                     #Extracting years
    df['Contract_end_year'][i]   = temp[1]
  else:
    df['Contract_start_year'][i] = 0
    df['Contract_end_year'][i] = 0
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-187-a6e1aa15807a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Contract_end_year'][i] = 0
# <ipython-input-187-a6e1aa15807a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Contract_end_year'][i]   = temp[1]
# <ipython-input-187-a6e1aa15807a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
df['Contract_start_year'] = df['Contract_start_year'].astype(int)    #Converting the columns to int datatype
df['Contract_end_year']   = df['Contract_end_year'].astype(int)

# %%
df = df[df['Contract_start_year'] != 0]
df = df[df['Contract_end_year'] != 0]

# %%
df = df.dropna(subset=['Contract_start_year', 'Contract_end_year'])

# %%
print(len(df))
# Out:
# 15818

# %%
print(df['Contract_start_year'].dtype)
print(df['Contract_end_year'].dtype)
# Out:
# int64
# int64

# %% [markdown]
# Backup copy 1

# %%
df_copy = df.copy()

# %% [markdown]
# Cleaning 'Height' column

# %%
def new_height(height):
  height_string = str(height)
  if height_string[len(height_string)-2:len(height_string)] == 'cm':  #check if last 2 digits are 'cm'
    return height_string[0:3]
  else:
    temp = height_string.split("'")  #spliting using ' as the separator
    temp_first_part = float(temp[0]) * 30.48
    temp_second_part = temp[1].split('"')   #splitting using " as the separator
    temp_second_part = float(temp_second_part[0]) * 2.54
    return (temp_first_part + temp_second_part)

df['new_height'] = df['Height'].apply(lambda x: new_height(x))

# %%
df.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
df['new_height'] = df['new_height'].astype(int)    #Converting the datatype of column from float to int

# %%
print(df['new_height'].dtype)
# Out:
# int64

# %% [markdown]
# Cleaning 'Weight' column

# %%
print(df['Weight'].dtype)
# Out:
# object

# %%
def weight_kg_lbs(weight):
  weight_string = str(weight)
  if weight_string[len(weight_string)-2:len(weight_string)] == 'kg':  #last 2 digits are kg
    return weight_string[0:len(weight_string)-2]

  elif weight_string[len(weight_string)-3:len(weight_string)] == 'lbs': #last 3 digits are lbs
    weight_lbs = weight_string[0:len(weight_string)-3]
    return (float(weight_lbs) * 0.45)                                   #returning weight in kg

# %%
df['Weight_in_kg'] = df['Weight'].apply(lambda x: weight_kg_lbs(x))

# %%
df['Weight_in_kg'] = df['Weight_in_kg'].astype(int)    #Converting weight column to int datatype

# %% [markdown]
# Cleaning 'Value' column
#
# *   Basically, this column has entries like 'â‚¬6.5M' and
#     'â‚¬825K'.
# *   We will convert the entries which are in 'K' to 'M' and we
#     will also remove 'â‚¬' from each entry.

# %%
print(df['Value'].dtype)
# Out:
# object

# %%
def clean_value(value):
  value_string = str(value)
  value_string_cleaned = value_string[1:len(value_string)]   #Extracting numeric part along with 'M' and 'K'
  #return value_string_cleaned

  if value_string_cleaned[-1] == 'K':
    value_float = (value_string_cleaned[0:len(value_string_cleaned)-1])  #Extracting numeric part and leaving 'M' and 'K'
    return float(value_float) * 0.001                         #Conversion into million

  elif value_string_cleaned[-1] == 'M':
    return value_string_cleaned[0:len(value_string_cleaned)-1]
  else:
    return value_string_cleaned

# %%
df['Value_cleaned_million_K'] = df['Value'].apply(lambda x: clean_value(x))
df['Cleaned_Value_in_million'] = df['Value_cleaned_million_K']

# %%
df = df.drop('Value_cleaned_million_K',axis = 1)

# %%
df['Cleaned_Value_in_million'] = df['Cleaned_Value_in_million'].astype(float)

# %%
print(df['Cleaned_Value_in_million'].dtype)
# Out:
# float64

# %% [markdown]
# Cleaning 'Wage' column
#
# *   This column has entries like 'â‚¬825K'.
# *   We will remove 'â‚¬' from each entry.

# %%
def clean_wage(wage):
  wage_string = str(wage)
  wage_string_cleaned = wage_string[1:len(wage_string)]
  if wage_string_cleaned[-1] == 'K':
    wage_float = (wage_string_cleaned[0:len(wage_string_cleaned)-1])
  else:  #for entries like '0'.'800'
    wage_float = wage_string_cleaned

  return (wage_float)

# %%
df['Cleaned_wages_in_K'] = df['Wage'].apply(lambda x: clean_wage(x))

# %%
df['Cleaned_wages_in_K'] = df['Cleaned_wages_in_K'].astype(float)

# %%
print(df['Cleaned_wages_in_K'].dtype)
# Out:
# float64

# %% [markdown]
# Cleaning 'Release Clause' column

# %% [markdown]
# *   Basically, this column has entries like 'â‚¬6.5M' and
#     'â‚¬825K'.
# *   We will convert the entries which are in 'K' to 'M' and we
#     will also remove 'â‚¬' from each entry.

# %%
def clean_release(release):
  release_string = str(release)
  release_string_cleaned = release_string[1:len(release_string)]   #Extracting numeric part along with 'M' and 'K'

  if release_string_cleaned[-1] == 'K':
    release_float = (release_string_cleaned[0:len(release_string_cleaned)-1])  #Extracting numeric part and leaving 'M' and 'K'
    return float(release_float) * 0.001                         #Conversion into million

  elif release_string_cleaned[-1] == 'M':
    return release_string_cleaned[0:len(release_string_cleaned)-1]
  else:
    return release_string_cleaned

# %%
df['Clean_release_value'] = df['Release Clause'].apply(lambda x: clean_release(x))

# %%
df['Clean_release_value'] = df['Clean_release_value'].astype(float)

# %% [markdown]
# Cleaning 'Hits' column

# %%
backup = df.copy()

# %%
df['Hits'].fillna(0,inplace = True)

# %%
def Convert_hits(hits):
  hits_string = str(hits)
  if hits_string[-1] == 'K':
    temp = hits_string[0:len(hits_string)-1]  #extracting numeric part
    return (float(temp)*1000)
  else:
    return hits_string

# %%
df['Hits_cleaned'] = df['Hits'].apply(lambda x: Convert_hits(x))

# %%
df['Hits_cleaned'] = df['Hits_cleaned'].astype(float)

# %%
df.to_csv('Fifa_modified_October_4_11_54_AM_modified.csv', index=False)
